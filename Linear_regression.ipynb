# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-4b324a59-57c1-4487-aa4a-5cc3fb41178e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b324a59-57c1-4487-aa4a-5cc3fb41178e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(data['Advertising (2).csv']))
print(df)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.plot(kind='scatter',x='TV',y='sales',color='red')
plt.show
df.plot(kind='scatter',x='radio',y='sales',color='green')
plt.show
df.plot(kind='scatter',x='newspaper',y='sales',color='black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = df.iloc[:,1:-1]
y = df.iloc[:, -1]
print(X)
print(y)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
model = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model.fit(X_train, y_train)
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [0.04405928 0.1992875  0.00688245]
# Intercept: 2.7089490925159065

# %%
X_test
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
# 195     7.6
# 29     10.5
# 19     14.6
# 143    10.4
# 86     12.0
# 114    14.6
# 173    11.7
# 5       7.2
# 126     6.6
# 117     9.4
# 73     11.0
# 140    10.9
# 98     25.4
# 172     7.6
# 96     11.7
# Name: sales, dtype: float64

# %%
x_pred_test=model.predict(X_test)
print("test data predictions of sales are:")
print(x_pred_test)
# Out:
# test data predictions of sales are:
# [16.5653963  21.18822792 21.55107058 10.88923816 22.20231988 13.35556872
#  21.19692502  7.35028523 13.27547079 15.12449511  9.01443026  6.52542825
#  14.30205991  8.97026042  9.45679576 12.00454351  8.91549403 16.15619251
#  10.29582883 18.72473553 19.76821818 13.77469028 12.49638908 21.53501762
#   7.60860741  5.6119801  20.91759483 11.80627665  9.08076637  8.51412012
#  12.17604891  9.9691939  21.73008956 12.77770578 18.1011362  20.07590796
#  14.26202556 20.93826535 10.83938827  4.38190607  9.51332406 12.40486324
#  10.17045434  8.09081363 13.16388427  5.2243552   9.28893833 14.09330719
#   8.69024497 11.66119763 15.71848432 11.63156862 13.35360735 11.1531472
#   6.33636845  9.76157954  9.4195714  24.25516546  7.69519137 12.15317572]

# %%
x_train_pred=model.predict(X_train)
print("training data prediction for sales are:")
print(x_train_pred)
# Out:
# training data prediction for sales are:
# [17.39149783 15.19196153 11.41650701 11.20610472 16.39256165  6.90577778
#  21.17740606  6.10528574  9.66662607 11.67308587  9.0704377   6.30582199
#  14.7930121  17.42999512 16.14599956 16.12273906 14.9308629  19.61593142
#  13.70741553 21.09067507 13.09101877 13.79551693  8.87971636 16.97348947
#   8.22902448 15.34026923 13.95862675 23.23157581 12.67992504 23.10768546
#   6.80057243 18.81832259 23.69669553 18.39890879 16.97890645 16.44055305
#  12.41657918 11.94072527 16.7732918  14.5933997  13.22910727  7.49691601
#  19.30121038  9.33105452 19.3603766  10.16463427  6.94369039 16.52918217
#  13.53571009 14.80225851 11.13948107 20.85632272 24.02985438 18.427486
#  17.84570024 15.11333638 17.21352856  9.2345359  17.29735156 19.22919752
#  16.29255016  3.54203145  5.24055709 15.86268553 15.12384811 16.31596188
#  18.34249185 23.4941462  14.34540589 20.48784226 17.29893239 21.67652708
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, x_pred_test)
mse = mean_squared_error(y_test, x_pred_test)
rmse = np.sqrt(mse)
print("on test data error is")

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("****************************")
print("on training data error is")
mae = mean_absolute_error(y_train, x_train_pred)
mse = mean_squared_error(y_train, x_train_pred)
rmse = np.sqrt(mse)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# on test data error is
# Mean Absolute Error: 1.5116692224549086
# Mean Squared Error: 3.79679723671522
# Root Mean Squared Error: 1.9485372043446387
# ****************************
# on training data error is
# Mean Absolute Error: 1.1581502948072526
# Mean Squared Error: 2.4793551789057866
# Root Mean Squared Error: 1.574596830590544

# %%
import statsmodels.api as sm
import pandas as pd


# Define the independent variables and add constant term
X = X_train[['TV', 'radio', 'newspaper']]  # Specify your predictor variables
X = sm.add_constant(X)  # Add a constant term

# Define the dependent variable
y = y_train

# Fit the regression model
model = sm.OLS(y, X).fit()



# Extract coefficients, standard errors, t-statistics, and p-values
anova_table = pd.DataFrame({
    'Coefficient': model.params,
    'Std. Error': model.bse,
    't-statistic': model.tvalues,
    'p-value': model.pvalues
})
print(anova_table)
# Out:
#            Coefficient  Std. Error  t-statistic       p-value
# const         2.708949    0.373668     7.249607  2.848109e-11
# TV            0.044059    0.001619    27.218741  6.788687e-57
# radio         0.199287    0.009868    20.195498  9.192647e-43
# newspaper     0.006882    0.006966     0.988001  3.249067e-01
